# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
xa = []
ya = []

id = 0
name = "Anna"
birthYear = 0
gender = "F"
state = "AK"
nameUsed = 0

with open("../data/names.csv", "r") as file:
#with open("../data/testnames.csv", "r") as file:     # Zum Testen die testnames.csv nutzen
    count = 0
    
    for line in file:
        
        count = count + 1

        line_split = line.strip().split(",")
        
        if line_split[1] == name and line_split[4] == state and line_split[3] == gender:
            
            xa.append(int(line_split[2]))
            ya.append(int(line_split[5]))
            # print(line_split)
            # break

print(xa)
print(ya)
# Out:
# ['1910', '1912', '1915', '1916', '1917', '1918', '1919', '1920', '1921', '1922', '1923', '1924', '1925', '1926', '1927', '1928', '1930', '1931', '1932', '1933', '1935', '1936', '1937', '1939', '1940', '1941', '1942', '1943', '1944', '1945', '1946', '1947', '1948', '1949', '1950', '1951', '1952', '1953', '1954', '1955', '1956', '1957', '1958', '1959', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014']
# ['10', '7', '10', '7', '5', '8', '5', '7', '6', '10', '12', '9', '7', '13', '7', '10', '10', '5', '9', '5', '9', '11', '8', '7', '7', '6', '9', '7', '5', '6', '6', '5', '11', '8', '8', '7', '13', '7', '15', '9', '18', '24', '9', '13', '13', '15', '20', '14', '15', '14', '13', '8', '20', '10', '18', '15', '9', '6', '15', '10', '19', '16', '9', '21', '15', '28', '26', '25', '28', '25', '25', '16', '28', '27', '27', '28', '25', '25', '19', '20', '21', '20', '17', '21', '34', '24', '25', '23', '26', '27', '16', '21', '21', '20', '22', '22', '10', '14', '18']

# %%
plt.plot(xa, ya)
plt.show()
