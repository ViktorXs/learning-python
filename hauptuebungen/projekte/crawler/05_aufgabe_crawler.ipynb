# %% [markdown]
# # Objektorientiert

# %% [markdown]
# ## Aufgabe: Crawler
#
# **Aufgabe:**
#
# - Passe den ArticleFetcher so an, dass er die Informationen aus allen Seiten extrahiert
#
# Hier nochmal die URL: http://python.beispiel.programmierenlernen.io/index.php
#
# **Tipps:**
#
# - Schau dir zuerst an, wie du den Button "Zur nächsten Seite" ansteuern kannst.
# - Wie greifst du von Python aus auf das "href" - Attribut dieses Buttons zu?
# - (Optional): Probier ggf. zuerst, nur die Infos der ersten 2 Seiten zu holen. Kannst du darauf aufbauend das Programm verallgemeinern, so dass es alle Seiten einliest?
# - Du kannst dich daran orientieren, ob es einen "Zur nächsten Seite"-Button gibt, oder nicht. Wenn es diesen Button nicht mehr gibt, bist du auf der letzten Seite angelangt. Welcher Schleifentyp bietet sich hier an, wenn du die Schleife erst dann stoppen willst, wenn es den Button nicht mehr gibt?

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import time  # Timer, um die Webseite bei einer Schleife vor versehentlichem request-spam zu schützen.

# %%
class CrawledArticle():  # Damit wird ein Artikel durch den ArticleFetcher gespeichert
    def __init__(self, title, emoji, content, image):
        self.title = title
        self.emoji = emoji
        self.content = content
        self.image = image
        
class ArticleFetcher():
    def fetch(self):
        url = "http://python.beispiel.programmierenlernen.io/index.php"
        articles = []

        while url != "":
            print(url)
            time.sleep(1)  # Hält das Programm für eine Sekunde an
            r = requests.get(url)
            page = BeautifulSoup(r.text, "html.parser")
            
            for card in page.select(".card"):
                title = card.select(".card-title span")[1].text
                emoji = card.select_one(".emoji").text
                content = card.select_one(".card-text").text
                image = urljoin(url, card.select_one("img").attrs["src"])
                
                crawled = CrawledArticle(title, emoji, content, image)
                articles.append(crawled)        
            
            next_button = page.select_one(".navigation .btn")
            if next_button:
                next_page = next_button.attrs["href"]
                next_page = urljoin(url, next_page)
                url = next_page
            else:
                url = ""
    
        return articles

# %%
fetcher = ArticleFetcher()
articles = fetcher.fetch()

for article in articles:
    print(article)
    print(article.emoji + " - " + article.title)
    print(article.content + article.image)
    print()
# Out:
# http://python.beispiel.programmierenlernen.io/index.php
# http://python.beispiel.programmierenlernen.io/index.php?page=2
# http://python.beispiel.programmierenlernen.io/index.php?page=3
# http://python.beispiel.programmierenlernen.io/index.php?page=4
# http://python.beispiel.programmierenlernen.io/index.php?page=5
# http://python.beispiel.programmierenlernen.io/index.php?page=6
# <__main__.CrawledArticle object at 0x0000017BAD4FD5B0>
# 😩 - Polarised modular conglomeration
# Optio numquam ut accusantium laborum unde assumenda. Ea et totam asperiores fugiat voluptatem vitae. Et provident nam et mollitia.http://python.beispiel.programmierenlernen.io/img/1.jpg
#
# <__main__.CrawledArticle object at 0x0000017BAD4FD610>
# 😐 - Cross-group contextually-based middleware
# Deleniti atque autem et commodi cupiditate cupiditate. Fuga illum quas aliquam velit. Labore dolor fugit quia id odio nam.http://python.beispiel.programmierenlernen.io/img/2.jpg
#
# <__main__.CrawledArticle object at 0x0000017BAD4FD670>
# 😌 - De-engineered encompassing structure
# Assumenda tempora inventore harum cumque voluptatibus sit et. Et omnis et dolore quod voluptas sit a.http://python.beispiel.programmierenlernen.io/img/3.jpg
#
# <__main__.CrawledArticle object at 0x0000017BAD4FD6D0>
# 😚 - Fully-configurable multi-tasking interface
# Cumque unde officia autem quia at fugit. Sint iure veritatis culpa aut provident aliquam in. Eos eum accusantium quia vel dignissimos nesciunt expedita. Rem aut accusantium et tempore.http://python.beispiel.programmierenlernen.io/img/4.jpg
#
# <__main__.CrawledArticle object at 0x0000017BAD4FD730>
# 😠 - Versatile eco-centric core
# Delectus distinctio quis omnis ut commodi sed. Beatae officia doloribus consequatur dolore. Consectetur impedit quia voluptas et ut. Incidunt rem mollitia fugiat quia corporis quo. Quod possimus ut et neque deserunt.http://python.beispiel.programmierenlernen.io/img/5.jpg
#
# <__main__.CrawledArticle object at 0x0000017BAD4FD790>
# 😮 - Optional maximized utilisation
# Consequatur sit deleniti sunt aut ullam eos. Vel ex ut sunt velit provident corporis consequatur. Ea est dolorum ut atque unde. Quasi itaque nihil pariatur.http://python.beispiel.programmierenlernen.io/img/6.jpg
#
# <__main__.CrawledArticle object at 0x0000017BAD4FD7F0>
# 😢 - Open-architected secondary product
# Reiciendis dolor quisquam tempora in. Totam ut distinctio vero. Ullam maiores dolor sunt voluptas.http://python.beispiel.programmierenlernen.io/img/7.jpg
#
# <__main__.CrawledArticle object at 0x0000017BAD4BFDC0>
# 😠 - Realigned zerotolerance function
# Consectetur doloribus sed quia id ex sequi. Accusamus repudiandae esse incidunt sunt minima sapiente quibusdam. Sit eius quasi non eius.http://python.beispiel.programmierenlernen.io/img/8.jpg
#
# <__main__.CrawledArticle object at 0x0000017BAD4BFE20>
# 😆 - Quality-focused user-facing help-desk
# Dolores ipsum tempore quae non corporis neque saepe. Nesciunt ipsam architecto et est. Illo fugit totam molestiae cumque consequatur. Qui veritatis necessitatibus repellendus.http://python.beispiel.programmierenlernen.io/img/9.jpg
#
# <__main__.CrawledArticle object at 0x0000017BAD4BFE80>
# 😤 - Proactive user-facing opensystem
# Quo recusandae iusto rem officia. Voluptatum placeat omnis nulla eum commodi iusto impedit. Alias qui a beatae commodi ducimus. Quo commodi nemo mollitia quaerat molestiae voluptate animi.http://python.beispiel.programmierenlernen.io/img/10.jpg
#
# <__main__.CrawledArticle object at 0x0000017BAD4BFEE0>
# 😟 - Decentralized holistic moderator
# Et autem voluptas nemo ab non. A error porro est facilis. Amet soluta quasi unde voluptas id magni.http://python.beispiel.programmierenlernen.io/img/11.jpg
#
# <__main__.CrawledArticle object at 0x0000017BAD4BFF40>
# 😌 - Mandatory tangible application
# Veniam neque perferendis dolor officia. Quis praesentium et et qui. Esse dicta asperiores doloremque eum facere odio quia. Voluptates odit et officia cumque aut velit quam.http://python.beispiel.programmierenlernen.io/img/12.jpg
#
# <__main__.CrawledArticle object at 0x0000017BAD4BFFA0>
# 😓 - Digitized dedicated budgetarymanagement
# Aliquam explicabo eius corporis perferendis. Cumque aperiam perferendis nesciunt et occaecati. Odit quisquam ullam non voluptatibus enim autem reiciendis. Officiis est dignissimos perferendis modi voluptas qui.http://python.beispiel.programmierenlernen.io/img/13.jpg
#
# <__main__.CrawledArticle object at 0x0000017BAD4BFFD0>
# 😞 - Organized well-modulated concept
# Quidem consequatur sed dolorem fuga. Est doloribus laudantium est blanditiis autem ut. Esse sapiente repellat et dolore minus voluptatem. Omnis dolores ipsam a explicabo et.http://python.beispiel.programmierenlernen.io/img/14.jpg
#
# <__main__.CrawledArticle object at 0x0000017BAD4FEA60>
# 😢 - Balanced optimal openarchitecture
# Eligendi sint velit dolor et cumque odio. Quia possimus nisi nostrum ullam et. Magnam quia id enim soluta modi quia esse. Sint quae vitae quidem beatae. Perspiciatis aliquam est impedit quis iusto.http://python.beispiel.programmierenlernen.io/img/15.jpg
#
# <__main__.CrawledArticle object at 0x0000017BAD4FEBE0>
# 😏 - Universal explicit throughput
# Magnam nobis soluta doloremque omnis architecto cum explicabo. Magnam alias tempora numquam sequi omnis tempora. Perferendis labore excepturi molestiae voluptate. Eum nihil ipsum et fuga quasi quidem id.http://python.beispiel.programmierenlernen.io/img/16.jpg
#
# <__main__.CrawledArticle object at 0x0000017BAD4FE8B0>
# 😳 - Polarised mobile algorithm
# Repellendus voluptatem impedit quis tempore sed suscipit. Eveniet qui quas optio quos tempora. Nemo sed qui placeat in autem fuga sunt minus.http://python.beispiel.programmierenlernen.io/img/17.jpg
#
# <__main__.CrawledArticle object at 0x0000017BAD4FEEE0>
# 😚 - Mandatory homogeneous infrastructure
# Deserunt quas ullam quia. Et voluptatibus accusantium autem in quaerat iure voluptatem. Assumenda dolores quos cum nemo molestias qui quia. Et qui autem repellat aperiam est deserunt.http://python.beispiel.programmierenlernen.io/img/18.jpg
#
# <__main__.CrawledArticle object at 0x0000017BAD4FEB20>
# 😲 - Business-focused interactive implementation
# Corporis eligendi voluptas dolorem sit consequatur ipsum. Aperiam et facere est voluptatem sit ea architecto repudiandae. Praesentium ducimus aperiam amet expedita dolores possimus. At soluta nihil dolor occaecati sint voluptatibus.http://python.beispiel.programmierenlernen.io/img/19.jpg
#
# <__main__.CrawledArticle object at 0x0000017BAD4FE0A0>
# 😯 - Polarised exuding archive
# Tenetur quaerat rerum nihil quo ratione qui molestiae amet. Ducimus occaecati ut sed reprehenderit porro. Sed quia sint ipsam repellendus. Iste libero laborum aspernatur illum ullam et soluta aut.http://python.beispiel.programmierenlernen.io/img/20.jpg
#
# <__main__.CrawledArticle object at 0x0000017BAD4FE040>
# 😵 - Extended homogeneous firmware
# Doloribus voluptas nam excepturi quibusdam. Ab esse architecto ut sunt. Non voluptates ex dolorem odit ab quasi.http://python.beispiel.programmierenlernen.io/img/21.jpg
#
# <__main__.CrawledArticle object at 0x0000017BACC6CA00>
# 😋 - Secured transitional capability
# Tenetur iusto nobis similique nobis laborum. Hic fuga in quia. Non molestias voluptatem dicta illum. Voluptatem aut repellendus est voluptatem voluptas.http://python.beispiel.programmierenlernen.io/img/22.jpg
#
# <__main__.CrawledArticle object at 0x0000017BACC6CFD0>
# 😴 - Expanded clear-thinking forecast
# Quo reiciendis quo veritatis. Et laboriosam ipsum molestias magni. Ea eveniet vel nihil autem et dignissimos. Ab magni iusto nulla est illo.http://python.beispiel.programmierenlernen.io/img/23.jpg
#
# <__main__.CrawledArticle object at 0x0000017BACC6CE20>
# 😇 - Grass-roots assymetric interface
# Itaque assumenda dolore dolor sed iste. Omnis sint sint blanditiis ut omnis. Nulla corporis dolor qui temporibus omnis dignissimos in.http://python.beispiel.programmierenlernen.io/img/24.jpg
#
# <__main__.CrawledArticle object at 0x0000017BACC6CD60>
# 😈 - Inverse static service-desk
# Eos qui ut eos accusamus sed. Et aut vel neque fuga sit vitae in dicta. Est perspiciatis culpa officia libero.http://python.beispiel.programmierenlernen.io/img/25.jpg
#
# <__main__.CrawledArticle object at 0x0000017BACC6CFA0>
# 😝 - Optional object-oriented toolset
# Ad id qui sed odio. Sequi voluptas voluptate provident pariatur doloremque. Dignissimos placeat harum repellendus magni.http://python.beispiel.programmierenlernen.io/img/26.jpg
#
# <__main__.CrawledArticle object at 0x0000017BACC6C9D0>
# 😧 - Optional stable service-desk
# Corrupti in tempore omnis et blanditiis. Tenetur qui qui corrupti nemo. Earum laboriosam dicta nulla sit quia impedit.http://python.beispiel.programmierenlernen.io/img/27.jpg
#
# <__main__.CrawledArticle object at 0x0000017BAD3C72B0>
# 😈 - Virtual background systemengine
# Voluptates sit debitis in eius aut. Odit modi minus impedit. Assumenda et ipsa fuga in cumque. Dignissimos qui qui doloribus consequatur ad. Saepe harum maxime illo nisi.http://python.beispiel.programmierenlernen.io/img/28.jpg
#
# <__main__.CrawledArticle object at 0x0000017BAD3B8880>
# 😶 - Balanced human-resource extranet
# Error sit quibusdam ducimus ullam. Dicta exercitationem libero excepturi maiores. Repudiandae provident sapiente cumque dolorem accusantium voluptatem.http://python.beispiel.programmierenlernen.io/img/29.jpg
#
# <__main__.CrawledArticle object at 0x0000017BAD3B8820>
# 😄 - Expanded bi-directional encryption
# Aspernatur quia consequatur molestiae saepe numquam et. Sed hic blanditiis consequuntur nostrum suscipit non hic. Voluptates sunt labore animi ea aut hic. Saepe quo doloribus eaque aspernatur.http://python.beispiel.programmierenlernen.io/img/30.jpg
#
# <__main__.CrawledArticle object at 0x0000017BAD3B8430>
# 😩 - Sharable client-driven groupware
# Nemo aut voluptatem unde non. Ducimus voluptates cumque quae earum ipsam. Aut vitae libero veniam nihil reprehenderit.http://python.beispiel.programmierenlernen.io/img/31.jpg
#
# <__main__.CrawledArticle object at 0x0000017BAD3B8550>
# 😬 - Monitored even-keeled initiative
# Distinctio quia nihil nam odit qui illum. Eos facilis et cumque maxime quasi veritatis sed.http://python.beispiel.programmierenlernen.io/img/32.jpg
#
# <__main__.CrawledArticle object at 0x0000017BAD3B8FD0>
# 😈 - Inverse maximized benchmark
# Nobis dolor magnam alias ut aliquam ea. Qui non sint dolor facere minima. Maiores nostrum et consequatur.http://python.beispiel.programmierenlernen.io/img/33.jpg
#
# <__main__.CrawledArticle object at 0x0000017BAD3B83A0>
# 😊 - Front-line full-range help-desk
# Sit tenetur aut dolores. Non exercitationem deleniti molestiae qui dolor. Magnam dolores eveniet at neque facilis molestiae quis et. Facere reiciendis porro impedit odio fugit similique consequatur.http://python.beispiel.programmierenlernen.io/img/34.jpg
#
# <__main__.CrawledArticle object at 0x0000017BAD3B8280>
# 😅 - Integrated impactful matrices
# Similique et et a laudantium. Veritatis quo et exercitationem est. Aut eum nihil non itaque sunt. Illum ea laudantium eum harum et ut.http://python.beispiel.programmierenlernen.io/img/35.jpg
#
# <__main__.CrawledArticle object at 0x0000017BAD4BBCA0>
# 😄 - Cross-platform composite data-warehouse
# Labore quia quo iusto incidunt natus. Perferendis consequatur quaerat dolorem quo.http://python.beispiel.programmierenlernen.io/img/36.jpg
#
# <__main__.CrawledArticle object at 0x0000017BAD4BBB50>
# 😴 - Grass-roots systemic support
# Amet recusandae necessitatibus doloremque. Iure harum accusantium nulla pariatur at delectus. Deserunt occaecati voluptas corrupti possimus harum. Officia atque sit magnam nulla voluptate.http://python.beispiel.programmierenlernen.io/img/37.jpg
#
# <__main__.CrawledArticle object at 0x0000017BAD4BB6A0>
# 😂 - Secured 3rdgeneration intranet
# Doloribus labore porro aspernatur blanditiis. Placeat enim culpa consequuntur maiores voluptatum. Ducimus et ad eos et.http://python.beispiel.programmierenlernen.io/img/38.jpg
#
# <__main__.CrawledArticle object at 0x0000017BAD4BB700>
# 😕 - Persistent composite firmware
# Eius quaerat vel debitis sed. Magnam et optio sit nemo sunt expedita. Qui eum quia qui porro cum delectus.http://python.beispiel.programmierenlernen.io/img/39.jpg
#
# <__main__.CrawledArticle object at 0x0000017BAD4BB3D0>
# 😊 - Upgradable multimedia benchmark
# Eos id quasi qui quo laboriosam eos eos. Sit sint quos deleniti voluptatem vel sint iste. Numquam minima qui dolore. Numquam vero quas repudiandae earum magni.http://python.beispiel.programmierenlernen.io/img/40.jpg
#
# <__main__.CrawledArticle object at 0x0000017BAD4BB970>
# 😦 - Organized fresh-thinking utilisation
# Laborum in id voluptatibus beatae non. Optio voluptates et eligendi veniam voluptas in suscipit. Quae numquam et ut sed. Velit fugit aut tenetur consequatur. Iusto blanditiis ut ut perspiciatis quod saepe.http://python.beispiel.programmierenlernen.io/img/41.jpg
